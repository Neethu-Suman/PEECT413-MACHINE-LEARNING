# %% [markdown]
# <a href="https://colab.research.google.com/github/Neethu-Suman/PEECT413-MACHINE-LEARNING/blob/main/Binary_Confusion_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Implementation of Confusion Matrix for Binary classification using Python**

# %% [markdown]
# Step 1: Import the necessary libraries

# %%
import numpy as np
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Step 2: Create the NumPy array for actual and predicted labels
#
# * actual: represents the true labels or the actual classification of the items. In this case it's a list of 10 items where each entry is either 'Dog' or 'Not Dog'.
# * predicted: represents the predicted labels or the classification made by the model.

# %%
actual    = np.array(['One','One','One','Zero','One','Zero','One','One','Zero','Zero'])
predicted = np.array(['One','Zero','One','Zero','One','One','One','One','Zero','Zero'])

# %% [markdown]
# Step 3: Compute the confusion matrix
#
# * confusion_matrix: This function from sklearn.metrics computes the confusion matrix which is a table used to evaluate the performance of a classification algorithm. It compares actual and predicted to generate a matrix

# %%
cm = confusion_matrix(actual,predicted)

# %% [markdown]
# Step 4: Plot the confusion matrix with ConfusionMatrixDisplay function
#
# *   `ConfusionMatrixDisplay`: This class from `sklearn.metrics` provides a convenient way to visualize a confusion matrix. It takes the computed confusion matrix and the display labels (the unique classes) as input to create a plottable object.
# *   `disp.plot(cmap=plt.cm.Blues)`: The `plot()` method of the `ConfusionMatrixDisplay` object generates the actual visualization. The `cmap` argument specifies the colormap to use for the heatmap, with `plt.cm.Blues` providing a blue color gradient.
# *   `plt.title('Confusion Matrix')`: This line sets the title of the generated plot to 'Confusion Matrix' for clarity.
# *   `plt.show()`: This command displays the plot. It's essential to call `plt.show()` to render the visualization when using Matplotlib.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# Create the ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Zero', 'One'])

# Plot the confusion matrix
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(actual, predicted))
# Out:
#               precision    recall  f1-score   support
#
#          One       0.83      0.83      0.83         6
#         Zero       0.75      0.75      0.75         4
#
#     accuracy                           0.80        10
#    macro avg       0.79      0.79      0.79        10
# weighted avg       0.80      0.80      0.80        10
